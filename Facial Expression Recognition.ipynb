# %%
import numpy as np
import seaborn as sns
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import os

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D
from keras.models import Model,Sequential
from tensorflow.keras.optimizers import Adam

# %%
pic_size = 48


# input path for the images
base_path = "/content/images/images/"

plt.figure(0, figsize=(12,20))
cpt = 0

for expression in os.listdir(base_path + "train/"):
    for i in range(1,6):
        cpt = cpt + 1
        plt.subplot(7,5,cpt)
        img = load_img(base_path + "train/" + expression + "/" +os.listdir(base_path + "train/" + expression)[i], target_size=(pic_size, pic_size))
        plt.imshow(img, cmap="gray")

plt.tight_layout()
plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator

# number of images to feed into the NN for every batch
batch_size = 128

datagen_train = ImageDataGenerator()
datagen_validation = ImageDataGenerator()

train_generator = datagen_train.flow_from_directory(base_path + "train",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = datagen_validation.flow_from_directory(base_path + "validation",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %%
no_of_classes=7
model=Sequential()

#1st CNN Layer
model.add(Conv2D(64,(3,3),padding='same', input_shape=(48,48,1)) )
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

#2nd CNN Layer
model.add(Conv2D(128,(5,5),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(.25))

#3rd CNN Layer
model.add(Conv2D(512,(3,3), padding=('same')))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

#4th CNN Layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

#fully connected 1st Layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

#Fully connected 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(no_of_classes, activation='softmax'))


opt=Adam(learning_rate=.0001)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 64)        640
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 48, 48, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 128)       204928
#
#  batch_normalization_1 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 24, 24, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 512)       590336
#
#  batch_normalization_2 (Batc  (None, 12, 12, 512)      2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 12, 12, 512)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 512)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 512)         0
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  batch_normalization_3 (Batc  (None, 6, 6, 512)        2048
#  hNormalization)
#
#  activation_3 (Activation)   (None, 6, 6, 512)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_5 (Activation)   (None, 512)               0
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
epochs = 50

from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit(x =train_generator,
                                steps_per_epoch=train_generator.n//train_generator.batch_size,
                                epochs=epochs,
                                validation_data = validation_generator,
                                validation_steps = validation_generator.n//validation_generator.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# Epoch 1/50
# 225/225 [==============================] - ETA: 0s - loss: 2.0547 - accuracy: 0.2309
# Epoch 00001: val_accuracy improved from -inf to 0.29020, saving model to model_weights.h5
# 225/225 [==============================] - 25s 60ms/step - loss: 2.0547 - accuracy: 0.2309 - val_loss: 1.7574 - val_accuracy: 0.2902
# Epoch 2/50
# 225/225 [==============================] - ETA: 0s - loss: 1.8278 - accuracy: 0.2958
# Epoch 00002: val_accuracy improved from 0.29020 to 0.34801, saving model to model_weights.h5
# 225/225 [==============================] - 13s 58ms/step - loss: 1.8278 - accuracy: 0.2958 - val_loss: 1.6656 - val_accuracy: 0.3480
# Epoch 3/50
# 225/225 [==============================] - ETA: 0s - loss: 1.7265 - accuracy: 0.3356
# Epoch 00003: val_accuracy improved from 0.34801 to 0.38409, saving model to model_weights.h5
# 225/225 [==============================] - 13s 58ms/step - loss: 1.7265 - accuracy: 0.3356 - val_loss: 1.5984 - val_accuracy: 0.3841
# Epoch 4/50
# 225/225 [==============================] - ETA: 0s - loss: 1.6516 - accuracy: 0.3655
# Epoch 00004: val_accuracy did not improve from 0.38409
# 225/225 [==============================] - 13s 58ms/step - loss: 1.6516 - accuracy: 0.3655 - val_loss: 1.6418 - val_accuracy: 0.3810
# Epoch 5/50
# 224/225 [============================>.] - ETA: 0s - loss: 1.5933 - accuracy: 0.3858
# Epoch 00005: val_accuracy did not improve from 0.38409
# 225/225 [==============================] - 14s 63ms/step - loss: 1.5931 - accuracy: 0.3860 - val_loss: 1.7180 - val_accuracy: 0.3773
# Epoch 6/50
# 225/225 [==============================] - ETA: 0s - loss: 1.5349 - accuracy: 0.4109
# Epoch 00006: val_accuracy improved from 0.38409 to 0.42812, saving model to model_weights.h5
# 225/225 [==============================] - 13s 60ms/step - loss: 1.5349 - accuracy: 0.4109 - val_loss: 1.5048 - val_accuracy: 0.4281
# Epoch 7/50
# 225/225 [==============================] - ETA: 0s - loss: 1.4870 - accuracy: 0.4270
# Epoch 00007: val_accuracy improved from 0.42812 to 0.44418, saving model to model_weights.h5
# 225/225 [==============================] - 14s 60ms/step - loss: 1.4870 - accuracy: 0.4270 - val_loss: 1.4767 - val_accuracy: 0.4442
# Epoch 8/50
# 225/225 [==============================] - ETA: 0s - loss: 1.4473 - accuracy: 0.4450
# Epoch 00008: val_accuracy improved from 0.44418 to 0.47301, saving model to model_weights.h5
# 225/225 [==============================] - 13s 60ms/step - loss: 1.4473 - accuracy: 0.4450 - val_loss: 1.3848 - val_accuracy: 0.4730
# Epoch 9/50
# 225/225 [==============================] - ETA: 0s - loss: 1.4080 - accuracy: 0.4593
# Epoch 00009: val_accuracy improved from 0.47301 to 0.48168, saving model to model_weights.h5
# 225/225 [==============================] - 13s 59ms/step - loss: 1.4080 - accuracy: 0.4593 - val_loss: 1.3838 - val_accuracy: 0.4817
# Epoch 10/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3643 - accuracy: 0.4786
# Epoch 00010: val_accuracy did not improve from 0.48168
# 225/225 [==============================] - 13s 59ms/step - loss: 1.3643 - accuracy: 0.4786 - val_loss: 1.4186 - val_accuracy: 0.4717
# Epoch 11/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3348 - accuracy: 0.4847
# Epoch 00011: val_accuracy did not improve from 0.48168
# 225/225 [==============================] - 13s 59ms/step - loss: 1.3348 - accuracy: 0.4847 - val_loss: 1.4251 - val_accuracy: 0.4760
# Epoch 12/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3063 - accuracy: 0.5004
# Epoch 00012: val_accuracy improved from 0.48168 to 0.53111, saving model to model_weights.h5
# 225/225 [==============================] - 13s 60ms/step - loss: 1.3063 - accuracy: 0.5004 - val_loss: 1.2353 - val_accuracy: 0.5311
# Epoch 13/50
# 224/225 [============================>.] - ETA: 0s - loss: 1.2765 - accuracy: 0.5138
# Epoch 00013: val_accuracy did not improve from 0.53111
# 225/225 [==============================] - 13s 59ms/step - loss: 1.2764 - accuracy: 0.5140 - val_loss: 1.2549 - val_accuracy: 0.5294
# Epoch 14/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2477 - accuracy: 0.5275
# Epoch 00014: val_accuracy did not improve from 0.53111
# 225/225 [==============================] - 14s 63ms/step - loss: 1.2477 - accuracy: 0.5275 - val_loss: 1.2782 - val_accuracy: 0.5190
# Epoch 15/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2259 - accuracy: 0.5306
# Epoch 00015: val_accuracy improved from 0.53111 to 0.53182, saving model to model_weights.h5
# 225/225 [==============================] - 14s 64ms/step - loss: 1.2259 - accuracy: 0.5306 - val_loss: 1.2546 - val_accuracy: 0.5318
# Epoch 16/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2028 - accuracy: 0.5416
# Epoch 00016: val_accuracy improved from 0.53182 to 0.54105, saving model to model_weights.h5
# 225/225 [==============================] - 15s 65ms/step - loss: 1.2028 - accuracy: 0.5416 - val_loss: 1.2069 - val_accuracy: 0.5411
# Epoch 17/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1829 - accuracy: 0.5504
# Epoch 00017: val_accuracy improved from 0.54105 to 0.55170, saving model to model_weights.h5
# 225/225 [==============================] - 14s 60ms/step - loss: 1.1829 - accuracy: 0.5504 - val_loss: 1.1874 - val_accuracy: 0.5517
# Epoch 18/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1685 - accuracy: 0.5546
# Epoch 00018: val_accuracy improved from 0.55170 to 0.56605, saving model to model_weights.h5
# 225/225 [==============================] - 13s 60ms/step - loss: 1.1685 - accuracy: 0.5546 - val_loss: 1.1396 - val_accuracy: 0.5661
# Epoch 19/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1414 - accuracy: 0.5652
# Epoch 00019: val_accuracy improved from 0.56605 to 0.56818, saving model to model_weights.h5
# 225/225 [==============================] - 14s 64ms/step - loss: 1.1414 - accuracy: 0.5652 - val_loss: 1.1656 - val_accuracy: 0.5682
# Epoch 20/50
# 224/225 [============================>.] - ETA: 0s - loss: 1.1229 - accuracy: 0.5721
# Epoch 00020: val_accuracy did not improve from 0.56818
# 225/225 [==============================] - 13s 59ms/step - loss: 1.1227 - accuracy: 0.5721 - val_loss: 1.1572 - val_accuracy: 0.5663
# Epoch 21/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1014 - accuracy: 0.5805
# Epoch 00021: val_accuracy improved from 0.56818 to 0.58977, saving model to model_weights.h5
# 225/225 [==============================] - 13s 59ms/step - loss: 1.1014 - accuracy: 0.5805 - val_loss: 1.0942 - val_accuracy: 0.5898
# Epoch 22/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0853 - accuracy: 0.5866
# Epoch 00022: val_accuracy did not improve from 0.58977
# 225/225 [==============================] - 13s 59ms/step - loss: 1.0853 - accuracy: 0.5866 - val_loss: 1.1272 - val_accuracy: 0.5768
# Epoch 23/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0629 - accuracy: 0.5972
# Epoch 00023: val_accuracy did not improve from 0.58977
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0629 - accuracy: 0.5972 - val_loss: 1.1158 - val_accuracy: 0.5848
# Epoch 24/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0565 - accuracy: 0.5996
# Epoch 00024: val_accuracy improved from 0.58977 to 0.59730, saving model to model_weights.h5
# 225/225 [==============================] - 14s 60ms/step - loss: 1.0565 - accuracy: 0.5996 - val_loss: 1.0949 - val_accuracy: 0.5973
# Epoch 25/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0338 - accuracy: 0.6091
# Epoch 00025: val_accuracy did not improve from 0.59730
# 225/225 [==============================] - 13s 59ms/step - loss: 1.0338 - accuracy: 0.6091 - val_loss: 1.0918 - val_accuracy: 0.5926
# Epoch 26/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0194 - accuracy: 0.6137
# Epoch 00026: val_accuracy did not improve from 0.59730
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0194 - accuracy: 0.6137 - val_loss: 1.0985 - val_accuracy: 0.5949
# Epoch 27/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0017 - accuracy: 0.6228
# Epoch 00027: val_accuracy improved from 0.59730 to 0.60824, saving model to model_weights.h5
# 225/225 [==============================] - 13s 60ms/step - loss: 1.0017 - accuracy: 0.6228 - val_loss: 1.0608 - val_accuracy: 0.6082
# Epoch 28/50
# 225/225 [==============================] - ETA: 0s - loss: 0.9878 - accuracy: 0.6266
# Epoch 00028: val_accuracy did not improve from 0.60824
# 225/225 [==============================] - 13s 60ms/step - loss: 0.9878 - accuracy: 0.6266 - val_loss: 1.0922 - val_accuracy: 0.5946
# Epoch 29/50
# 225/225 [==============================] - ETA: 0s - loss: 0.9782 - accuracy: 0.6334
# Epoch 00029: val_accuracy improved from 0.60824 to 0.60866, saving model to model_weights.h5
# 225/225 [==============================] - 13s 60ms/step - loss: 0.9782 - accuracy: 0.6334 - val_loss: 1.0645 - val_accuracy: 0.6087
# Epoch 30/50
# 225/225 [==============================] - ETA: 0s - loss: 0.9585 - accuracy: 0.6373
# Epoch 00030: val_accuracy improved from 0.60866 to 0.62259, saving model to model_weights.h5
# 225/225 [==============================] - 13s 60ms/step - loss: 0.9585 - accuracy: 0.6373 - val_loss: 1.0365 - val_accuracy: 0.6226
# Epoch 31/50
# 225/225 [==============================] - ETA: 0s - loss: 0.9530 - accuracy: 0.6429
# Epoch 00031: val_accuracy improved from 0.62259 to 0.62358, saving model to model_weights.h5
# 225/225 [==============================] - 13s 60ms/step - loss: 0.9530 - accuracy: 0.6429 - val_loss: 1.0375 - val_accuracy: 0.6236
# Epoch 32/50
# 225/225 [==============================] - ETA: 0s - loss: 0.9251 - accuracy: 0.6535
# Epoch 00032: val_accuracy did not improve from 0.62358
# 225/225 [==============================] - 13s 59ms/step - loss: 0.9251 - accuracy: 0.6535 - val_loss: 1.0722 - val_accuracy: 0.6074
# Epoch 33/50
# 225/225 [==============================] - ETA: 0s - loss: 0.9124 - accuracy: 0.6573
# Epoch 00033: val_accuracy improved from 0.62358 to 0.62443, saving model to model_weights.h5
# 225/225 [==============================] - 14s 60ms/step - loss: 0.9124 - accuracy: 0.6573 - val_loss: 1.0362 - val_accuracy: 0.6244
# Epoch 34/50
# 225/225 [==============================] - ETA: 0s - loss: 0.8948 - accuracy: 0.6627
# Epoch 00034: val_accuracy did not improve from 0.62443
# 225/225 [==============================] - 13s 59ms/step - loss: 0.8948 - accuracy: 0.6627 - val_loss: 1.0501 - val_accuracy: 0.6222
# Epoch 35/50
# 224/225 [============================>.] - ETA: 0s - loss: 0.8753 - accuracy: 0.6722
# Epoch 00035: val_accuracy improved from 0.62443 to 0.63509, saving model to model_weights.h5
# 225/225 [==============================] - 14s 60ms/step - loss: 0.8754 - accuracy: 0.6721 - val_loss: 1.0367 - val_accuracy: 0.6351
# Epoch 36/50
# 225/225 [==============================] - ETA: 0s - loss: 0.8659 - accuracy: 0.6741
# Epoch 00036: val_accuracy did not improve from 0.63509
# 225/225 [==============================] - 13s 59ms/step - loss: 0.8659 - accuracy: 0.6741 - val_loss: 1.0403 - val_accuracy: 0.6251
# Epoch 37/50
# 225/225 [==============================] - ETA: 0s - loss: 0.8513 - accuracy: 0.6816
# Epoch 00037: val_accuracy did not improve from 0.63509
# 225/225 [==============================] - 14s 64ms/step - loss: 0.8513 - accuracy: 0.6816 - val_loss: 1.0583 - val_accuracy: 0.6277
# Epoch 38/50
# 225/225 [==============================] - ETA: 0s - loss: 0.8353 - accuracy: 0.6877
# Epoch 00038: val_accuracy improved from 0.63509 to 0.63849, saving model to model_weights.h5
# 225/225 [==============================] - 13s 60ms/step - loss: 0.8353 - accuracy: 0.6877 - val_loss: 1.0262 - val_accuracy: 0.6385
# Epoch 39/50
# 225/225 [==============================] - ETA: 0s - loss: 0.8191 - accuracy: 0.6893
# Epoch 00039: val_accuracy did not improve from 0.63849
# 225/225 [==============================] - 13s 59ms/step - loss: 0.8191 - accuracy: 0.6893 - val_loss: 1.0869 - val_accuracy: 0.6187
# Epoch 40/50
# 225/225 [==============================] - ETA: 0s - loss: 0.8053 - accuracy: 0.6954
# Epoch 00040: val_accuracy did not improve from 0.63849
# 225/225 [==============================] - 13s 59ms/step - loss: 0.8053 - accuracy: 0.6954 - val_loss: 1.0539 - val_accuracy: 0.6263
# Epoch 41/50
# 225/225 [==============================] - ETA: 0s - loss: 0.7901 - accuracy: 0.7040
# Epoch 00041: val_accuracy did not improve from 0.63849
# 225/225 [==============================] - 13s 59ms/step - loss: 0.7901 - accuracy: 0.7040 - val_loss: 1.0665 - val_accuracy: 0.6366
# Epoch 42/50
# 224/225 [============================>.] - ETA: 0s - loss: 0.7727 - accuracy: 0.7108
# Epoch 00042: val_accuracy improved from 0.63849 to 0.63977, saving model to model_weights.h5
# 225/225 [==============================] - 13s 60ms/step - loss: 0.7728 - accuracy: 0.7107 - val_loss: 1.0421 - val_accuracy: 0.6398
# Epoch 43/50
# 225/225 [==============================] - ETA: 0s - loss: 0.7581 - accuracy: 0.7161
# Epoch 00043: val_accuracy did not improve from 0.63977
# 225/225 [==============================] - 13s 58ms/step - loss: 0.7581 - accuracy: 0.7161 - val_loss: 1.0530 - val_accuracy: 0.6320
# Epoch 44/50
# 225/225 [==============================] - ETA: 0s - loss: 0.7485 - accuracy: 0.7232
# Epoch 00044: val_accuracy did not improve from 0.63977
# 225/225 [==============================] - 13s 59ms/step - loss: 0.7485 - accuracy: 0.7232 - val_loss: 1.0474 - val_accuracy: 0.6355
# Epoch 45/50
# 224/225 [============================>.] - ETA: 0s - loss: 0.7375 - accuracy: 0.7205
# Epoch 00045: val_accuracy improved from 0.63977 to 0.64560, saving model to model_weights.h5
# 225/225 [==============================] - 13s 59ms/step - loss: 0.7372 - accuracy: 0.7206 - val_loss: 1.0116 - val_accuracy: 0.6456
# Epoch 46/50
# 225/225 [==============================] - ETA: 0s - loss: 0.7184 - accuracy: 0.7342
# Epoch 00046: val_accuracy did not improve from 0.64560
# 225/225 [==============================] - 14s 63ms/step - loss: 0.7184 - accuracy: 0.7342 - val_loss: 1.0123 - val_accuracy: 0.6440
# Epoch 47/50
# 225/225 [==============================] - ETA: 0s - loss: 0.7082 - accuracy: 0.7342
# Epoch 00047: val_accuracy did not improve from 0.64560
# 225/225 [==============================] - 13s 59ms/step - loss: 0.7082 - accuracy: 0.7342 - val_loss: 1.0417 - val_accuracy: 0.6388
# Epoch 48/50
# 225/225 [==============================] - ETA: 0s - loss: 0.6889 - accuracy: 0.7427
# Epoch 00048: val_accuracy did not improve from 0.64560
# 225/225 [==============================] - 13s 59ms/step - loss: 0.6889 - accuracy: 0.7427 - val_loss: 1.0614 - val_accuracy: 0.6433
# Epoch 49/50
# 225/225 [==============================] - ETA: 0s - loss: 0.6824 - accuracy: 0.7459
# Epoch 00049: val_accuracy did not improve from 0.64560
# 225/225 [==============================] - 14s 60ms/step - loss: 0.6824 - accuracy: 0.7459 - val_loss: 1.0545 - val_accuracy: 0.6379
# Epoch 50/50
# 225/225 [==============================] - ETA: 0s - loss: 0.6659 - accuracy: 0.7503
# Epoch 00050: val_accuracy did not improve from 0.64560
# 225/225 [==============================] - 13s 59ms/step - loss: 0.6659 - accuracy: 0.7503 - val_loss: 1.0495 - val_accuracy: 0.6399

# %%
plt.figure(figsize=(24,8))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
